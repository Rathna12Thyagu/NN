# %%
import pandas as pd
import numpy as np

# %%
d = pd.read_csv('../input/digit-recognizer/train.csv')
d.head()
d.shape
# Out:
# (42000, 785)

# %%
hidden = 100
ite = 5000
inp = 784
out = 10
weight=[]
weight.append(np.random.randn(784,hidden))
weight.append(np.random.randn(hidden,10))
bias = np.random.randn()

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))
func1 = (np.dot(x_test,weight[0]))+bias
x = sigmoid(func1)
func2 = (np.dot(x,weight[1])+bias)
x1 = sigmoid(func2)
print(x1)
print(x1.shape)
# Out:
# [[2.23329079e-03 5.18244012e-05 2.17171945e-01 ... 9.99528489e-01
#   9.74962731e-01 9.99415650e-01]
#  [4.85481172e-02 4.86307861e-03 9.65969965e-01 ... 9.99996795e-01
#   9.96056305e-01 1.00000000e+00]
#  [4.78327952e-06 7.37510606e-05 2.08345542e-04 ... 9.99950986e-01
#   2.19222215e-02 9.99994617e-01]
#  ...
#  [2.35602932e-04 9.56095498e-05 8.78091779e-01 ... 9.98868031e-01
#   4.29728321e-01 9.99932159e-01]
#  [9.55194818e-01 1.02913535e-06 1.08655155e-01 ... 9.99939917e-01
#   9.15875040e-01 9.99979182e-01]
#  [3.71698835e-02 1.08209787e-06 7.90845106e-01 ... 9.76967573e-01
#   9.69996577e-01 9.99149306e-01]]
# (42000, 10)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp

# %%
maxi=[]
for i in range(42000):
    t = np.argmax(x2[i][:])
    maxi.append(t)
    #print(max)

# %%
#accuracy
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test,maxi)
print(score)
# Out:
# 0.10016666666666667
